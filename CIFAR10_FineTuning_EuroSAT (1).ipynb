# %% [markdown]
# CIFAR10

# %% [markdown]
# customize model

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
import datetime
import os

# ------------------------------
# Configuration
# ------------------------------
BATCH_SIZE = 64
NUM_CLASSES = 10
EPOCHS = 50  # Increased to allow EarlyStopping to work
FINAL_CROP_SHAPE = (24, 24, 3)

# Model architecture parameters
CONV_FILTERS = [64, 128]  # Number of filters in each conv block
DENSE_UNITS = [512, 256]  # Units in dense layers (before final output)

# ------------------------------
# 1. Data Loading and Preprocessing
# ------------------------------
print("Loading and preparing CIFAR-10 data...")
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

# Keep labels as integers (not one-hot) for sparse loss
y_train = y_train.squeeze()  # shape: (50000,)
y_test = y_test.squeeze()     # shape: (10000,)

def apply_augmentation_and_norm(img, label):
    img = tf.cast(img, tf.float32)
    img = tf.image.random_crop(img, size=[24, 24, 3])
    img = tf.image.random_flip_left_right(img)
    mean = tf.reduce_mean(img)
    std = tf.math.reduce_std(img)
    img = (img - mean) / (std + 1e-7)
    return img, label

def apply_norm_only(img, label):
    img = tf.cast(img, tf.float32)
    img = tf.image.resize_with_crop_or_pad(img, 24, 24)  # center crop
    mean = tf.reduce_mean(img)
    std = tf.math.reduce_std(img)
    img = (img - mean) / (std + 1e-7)
    return img, label

# Build datasets
train_ds = tf.data.Dataset.from_tensor_slices((x_train, y_train))
train_dl = (
    train_ds
    .shuffle(10000)
    .map(apply_augmentation_and_norm, num_parallel_calls=tf.data.AUTOTUNE)
    .batch(BATCH_SIZE)
    .prefetch(tf.data.AUTOTUNE)
)

test_ds = tf.data.Dataset.from_tensor_slices((x_test, y_test))
test_dl = (
    test_ds
    .map(apply_norm_only, num_parallel_calls=tf.data.AUTOTUNE)
    .batch(BATCH_SIZE)
    .prefetch(tf.data.AUTOTUNE)
)

# ------------------------------
# 2. Model Definition (Customizable)
# ------------------------------
def get_cnn_model(input_shape, conv_filters, dense_units, num_classes=10):
    W_init_conv = tf.keras.initializers.TruncatedNormal(stddev=5e-2)
    W_init_dense = tf.keras.initializers.TruncatedNormal(stddev=0.04)
    b_init_dense = tf.keras.initializers.Constant(value=0.1)

    inputs = tf.keras.Input(shape=input_shape)
    x = inputs

    # Convolutional blocks
    for i, filters in enumerate(conv_filters):
        x = tf.keras.layers.Conv2D(
            filters=filters,
            kernel_size=5,
            padding='same',
            kernel_initializer=W_init_conv,
            use_bias=False
        )(x)
        x = tf.keras.layers.BatchNormalization(momentum=0.99)(x)
        x = tf.keras.layers.ReLU()(x)
        x = tf.keras.layers.MaxPooling2D(pool_size=3, strides=2, padding='same')(x)
        if i == 0:  # Add dropout after first conv block
            x = tf.keras.layers.Dropout(0.25)(x)

    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dropout(0.5)(x)  # Dropout before dense layers

    # Dense layers
    for units in dense_units:
        x = tf.keras.layers.Dense(
            units,
            activation='relu',
            kernel_initializer=W_init_dense,
            bias_initializer=b_init_dense
        )(x)
        x = tf.keras.layers.Dropout(0.5)(x)

    outputs = tf.keras.layers.Dense(
        num_classes,
        activation=None,
        kernel_initializer=W_init_dense,
        bias_initializer=b_init_dense
    )(x)

    return tf.keras.Model(inputs=inputs, outputs=outputs, name='custom_cnn')

model = get_cnn_model(
    input_shape=FINAL_CROP_SHAPE,
    conv_filters=CONV_FILTERS,
    dense_units=DENSE_UNITS,
    num_classes=NUM_CLASSES
)

print("\n✅ Model Architecture:")
model.summary()

# ------------------------------
# 3. Callbacks Setup
# ------------------------------
# Create log directory for TensorBoard
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(
    log_dir=log_dir, histogram_freq=1
)

# Early Stopping
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True,
    verbose=1
)

# List of callbacks
callbacks = [tensorboard_callback, early_stopping]

# ------------------------------
# 4. Compile and Train
# ------------------------------
model.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy']
)

print(f"\n🚀 Starting training for up to {EPOCHS} epochs...")
history = model.fit(
    train_dl,
    epochs=EPOCHS,
    validation_data=test_dl,
    callbacks=callbacks,
    verbose=1
)

# ------------------------------
# 5. Final Test Accuracy
# ------------------------------
test_loss, test_accuracy = model.evaluate(test_dl, verbose=0)
print(f"\n🎯 Final Test Accuracy: {test_accuracy:.4f} ({test_accuracy*100:.2f}%)")

# ------------------------------
# 6. Plot Training History
# ------------------------------
def plot_training_history(history):
    fig, ax = plt.subplots(1, 2, figsize=(12, 4))

    # Accuracy
    ax[0].plot(history.history['accuracy'], label='Train Accuracy')
    ax[0].plot(history.history['val_accuracy'], label='Val Accuracy')
    ax[0].set_title('Model Accuracy')
    ax[0].set_xlabel('Epoch')
    ax[0].set_ylabel('Accuracy')
    ax[0].legend()

    # Loss
    ax[1].plot(history.history['loss'], label='Train Loss')
    ax[1].plot(history.history['val_loss'], label='Val Loss')
    ax[1].set_title('Model Loss')
    ax[1].set_xlabel('Epoch')
    ax[1].set_ylabel('Loss')
    ax[1].legend()

    plt.tight_layout()
    plt.savefig('training_history.png', dpi=150)
    plt.show()

plot_training_history(history)

# ------------------------------
# 7. Confusion Matrix
# ------------------------------
print("\n📊 Generating Confusion Matrix...")
# Get predictions
y_pred_logits = model.predict(test_dl)
y_pred = np.argmax(y_pred_logits, axis=1)

# Flatten true labels
y_true = y_test  # shape (10000,)

cm = confusion_matrix(y_true, y_pred, normalize='true')
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=False, cmap='Blues', square=True)
plt.title('Normalized Confusion Matrix')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.savefig('confusion_matrix.png', dpi=150)
plt.show()

# ------------------------------
# 8. Display Sample Images with Predictions
# ------------------------------
print("\n🖼️ Displaying Sample Images with Predictions...")

# Get a few test images (original size 32x32)
sample_indices = np.random.choice(len(x_test), 9, replace=False)
sample_images = x_test[sample_indices]
sample_true_labels = y_test[sample_indices]

# Preprocess for model (24x24 + norm)
def preprocess_for_model(img):
    img = tf.cast(img, tf.float32)
    img = tf.image.resize_with_crop_or_pad(img, 24, 24)
    mean = tf.reduce_mean(img)
    std = tf.math.reduce_std(img)
    img = (img - mean) / (std + 1e-7)
    return img

preprocessed = np.array([preprocess_for_model(img) for img in sample_images])
predictions = model.predict(preprocessed)
predicted_labels = np.argmax(predictions, axis=1)
confidence = np.max(tf.nn.softmax(predictions), axis=1)

# CIFAR-10 class names
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

# Plot
fig, axes = plt.subplots(3, 3, figsize=(10, 10))
axes = axes.ravel()

for i in range(9):
    # Display original 32x32 image
    axes[i].imshow(sample_images[i])
    axes[i].set_title(
        f'True: {class_names[sample_true_labels[i]]}\n'
        f'Pred: {class_names[predicted_labels[i]]}\n'
        f'Conf: {confidence[i]:.2f}',
        fontsize=10
    )
    axes[i].axis('off')

plt.tight_layout()
plt.savefig('sample_predictions.png', dpi=150)
plt.show()

print(f"📊 Training plots saved as 'training_history.png'")
print(f"🧩 Confusion matrix saved as 'confusion_matrix.png'")
print(f"🖼️ Sample predictions saved as 'sample_predictions.png'")
print(f"📉 TensorBoard logs saved to: {log_dir}")
print("\nTo view TensorBoard, run in terminal:")
print(f"tensorboard --logdir {os.path.abspath(log_dir)}")
# Out:
# Loading and preparing CIFAR-10 data...
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 13s 0us/step
#
# ✅ Model Architecture:
# Model: "custom_cnn"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 24, 24, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 24, 24, 64)     │         4,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 24, 24, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu (ReLU)                    │ (None, 24, 24, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 12, 12, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 12, 12, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 12, 12, 128)    │       204,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 12, 12, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_1 (ReLU)                  │ (None, 12, 12, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 6, 6, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 4608)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 4608)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,704,074 (10.32 MB)
#  Trainable params: 2,703,690 (10.31 MB)
#  Non-trainable params: 384 (1.50 KB)
# 🚀 Starting training for up to 50 epochs...
# Epoch 1/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 22s 18ms/step - accuracy: 0.2687 - loss: 1.9379 - val_accuracy: 0.4024 - val_loss: 1.6261
# Epoch 2/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.3836 - loss: 1.6651 - val_accuracy: 0.4947 - val_loss: 1.4652
# Epoch 3/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.4367 - loss: 1.5452 - val_accuracy: 0.5505 - val_loss: 1.3289
# Epoch 4/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.4743 - loss: 1.4691 - val_accuracy: 0.5754 - val_loss: 1.2792
# Epoch 5/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.5051 - loss: 1.3971 - val_accuracy: 0.5957 - val_loss: 1.1948
# Epoch 6/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.5314 - loss: 1.3405 - val_accuracy: 0.6071 - val_loss: 1.1453
# Epoch 7/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.5472 - loss: 1.3007 - val_accuracy: 0.6512 - val_loss: 1.0977
# Epoch 8/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.5657 - loss: 1.2561 - val_accuracy: 0.6713 - val_loss: 1.0603
# Epoch 9/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.5811 - loss: 1.2138 - val_accuracy: 0.6743 - val_loss: 1.0137
# Epoch 10/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.5893 - loss: 1.1959 - val_accuracy: 0.6697 - val_loss: 1.0231
# Epoch 11/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.6005 - loss: 1.1616 - val_accuracy: 0.6952 - val_loss: 0.9646
# Epoch 12/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.6126 - loss: 1.1381 - val_accuracy: 0.7097 - val_loss: 0.9358
# Epoch 13/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.6203 - loss: 1.1174 - val_accuracy: 0.7071 - val_loss: 0.9288
# Epoch 14/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.6265 - loss: 1.0986 - val_accuracy: 0.6989 - val_loss: 0.9193
# Epoch 15/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.6317 - loss: 1.0818 - val_accuracy: 0.6955 - val_loss: 0.9003
# Epoch 16/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.6391 - loss: 1.0650 - val_accuracy: 0.7162 - val_loss: 0.8983
# Epoch 17/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.6424 - loss: 1.0553 - val_accuracy: 0.7093 - val_loss: 0.8791
# Epoch 18/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.6501 - loss: 1.0350 - val_accuracy: 0.7341 - val_loss: 0.8255
# Epoch 19/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.6545 - loss: 1.0264 - val_accuracy: 0.7142 - val_loss: 0.8613
# Epoch 20/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.6573 - loss: 1.0141 - val_accuracy: 0.7374 - val_loss: 0.8070
# Epoch 21/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.6645 - loss: 0.9904 - val_accuracy: 0.7259 - val_loss: 0.8159
# Epoch 22/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.6657 - loss: 0.9949 - val_accuracy: 0.7367 - val_loss: 0.8033
# Epoch 23/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.6697 - loss: 0.9760 - val_accuracy: 0.7504 - val_loss: 0.7684
# Epoch 24/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.6741 - loss: 0.9661 - val_accuracy: 0.7422 - val_loss: 0.7788
# Epoch 25/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.6769 - loss: 0.9556 - val_accuracy: 0.7554 - val_loss: 0.7553
# Epoch 26/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.6823 - loss: 0.9468 - val_accuracy: 0.7491 - val_loss: 0.7557
# Epoch 27/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.6831 - loss: 0.9385 - val_accuracy: 0.7621 - val_loss: 0.7160
# Epoch 28/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.6876 - loss: 0.9311 - val_accuracy: 0.7593 - val_loss: 0.7271
# Epoch 29/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.6909 - loss: 0.9248 - val_accuracy: 0.7534 - val_loss: 0.7514
# Epoch 30/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.6913 - loss: 0.9166 - val_accuracy: 0.7517 - val_loss: 0.7291
# Epoch 31/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.6940 - loss: 0.9118 - val_accuracy: 0.7662 - val_loss: 0.6971
# Epoch 32/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.6988 - loss: 0.8998 - val_accuracy: 0.7597 - val_loss: 0.7154
# Epoch 33/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.6988 - loss: 0.8953 - val_accuracy: 0.7694 - val_loss: 0.7008
# Epoch 34/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.7023 - loss: 0.8922 - val_accuracy: 0.7649 - val_loss: 0.6948
# Epoch 35/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.7005 - loss: 0.8893 - val_accuracy: 0.7700 - val_loss: 0.6874
# Epoch 36/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.7054 - loss: 0.8763 - val_accuracy: 0.7579 - val_loss: 0.6998
# Epoch 37/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.7067 - loss: 0.8720 - val_accuracy: 0.7781 - val_loss: 0.6716
# Epoch 38/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.7076 - loss: 0.8703 - val_accuracy: 0.7777 - val_loss: 0.6794
# Epoch 39/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.7098 - loss: 0.8681 - val_accuracy: 0.7764 - val_loss: 0.6747
# Epoch 40/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 10ms/step - accuracy: 0.7155 - loss: 0.8641 - val_accuracy: 0.7758 - val_loss: 0.6684
# Epoch 41/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.7125 - loss: 0.8588 - val_accuracy: 0.7692 - val_loss: 0.6835
# Epoch 42/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.7155 - loss: 0.8459 - val_accuracy: 0.7668 - val_loss: 0.6732
# Epoch 43/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.7181 - loss: 0.8446 - val_accuracy: 0.7860 - val_loss: 0.6516
# Epoch 44/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.7167 - loss: 0.8448 - val_accuracy: 0.7783 - val_loss: 0.6548
# Epoch 45/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.7155 - loss: 0.8434 - val_accuracy: 0.7880 - val_loss: 0.6607
# Epoch 46/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.7204 - loss: 0.8407 - val_accuracy: 0.7750 - val_loss: 0.6855
# Epoch 47/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.7207 - loss: 0.8358 - val_accuracy: 0.7760 - val_loss: 0.6534
# Epoch 48/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.7233 - loss: 0.8280 - val_accuracy: 0.7865 - val_loss: 0.6350
# Epoch 49/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 10ms/step - accuracy: 0.7276 - loss: 0.8188 - val_accuracy: 0.7870 - val_loss: 0.6447
# Epoch 50/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.7238 - loss: 0.8280 - val_accuracy: 0.7887 - val_loss: 0.6419
# Restoring model weights from the end of the best epoch: 48.
#
# 🎯 Final Test Accuracy: 0.7865 (78.65%)
# 📊 Generating Confusion Matrix...
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step
# 🖼️ Displaying Sample Images with Predictions...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 797ms/step
# 📊 Training plots saved as 'training_history.png'
# 🧩 Confusion matrix saved as 'confusion_matrix.png'
# 🖼️ Sample predictions saved as 'sample_predictions.png'
# 📉 TensorBoard logs saved to: logs/fit/20260627-094510
#
# To view TensorBoard, run in terminal:
# tensorboard --logdir /content/logs/fit/20260627-094510

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# EuroSat Dataset

# %%
print(train_ds.class_names)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1980/2446216301.py in <cell line: 0>()
# ----> 1 print(train_ds.class_names)
#
# AttributeError: '_TensorSliceDataset' object has no attribute 'class_names'

# %%
import matplotlib.pyplot as plt
for images, labels in train_dl.take(1):
    plt.imshow(images[0].numpy())
    plt.title(f"Label: {labels[0]}")
    plt.show()

# %%
import tensorflow as tf
import pathlib
import os
import kagglehub
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix

# 1. دانلود و تنظیم مسیر دیتاست
path = kagglehub.dataset_download("apollo2506/eurosat-dataset")
data_dir = pathlib.Path(path) / "EuroSAT"

# ------------------------------
# Configuration
# ------------------------------
BATCH_SIZE = 64
EPOCHS = 50
IMG_SIZE = (64, 64)
SAVE_DIR = "pretrained_eurosat"

# ------------------------------
# 1. Data Loading
# ------------------------------
print("Loading EuroSAT dataset from directory...")

train_ds = tf.keras.utils.image_dataset_from_directory(
    data_dir, validation_split=0.2, subset="training", seed=42,
    image_size=IMG_SIZE, batch_size=BATCH_SIZE
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    data_dir, validation_split=0.2, subset="validation", seed=42,
    image_size=IMG_SIZE, batch_size=BATCH_SIZE
)

class_names = train_ds.class_names
print(f"Classes found: {class_names}")

def prepare_ds(ds, augment=False):
    rescale = tf.keras.layers.Rescaling(1./255)
    ds = ds.map(lambda x, y: (rescale(x), y), num_parallel_calls=tf.data.AUTOTUNE)
    if augment:
        data_augmentation = tf.keras.Sequential([
            tf.keras.layers.RandomFlip("horizontal_and_vertical"),
            tf.keras.layers.RandomRotation(0.2),
            tf.keras.layers.RandomZoom(0.1),
        ])
        ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), num_parallel_calls=tf.data.AUTOTUNE)
    return ds.prefetch(tf.data.AUTOTUNE)

train_dl = prepare_ds(train_ds, augment=True)
test_dl = prepare_ds(val_ds, augment=False)

# ------------------------------
# 2. Model Definition
# ------------------------------
def build_eurosat_model(input_shape=(64, 64, 3), num_classes=10):
    inputs = tf.keras.Input(shape=input_shape)
    x = tf.keras.layers.Conv2D(64, 5, padding='same', kernel_initializer='he_uniform')(inputs)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.ReLU()(x)
    x = tf.keras.layers.MaxPooling2D(3, strides=2, padding='same')(x)

    x = tf.keras.layers.Conv2D(128, 5, padding='same', kernel_initializer='he_uniform')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.ReLU()(x)
    x = tf.keras.layers.MaxPooling2D(3, strides=2, padding='same')(x)

    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dense(512, activation='relu', kernel_initializer='he_uniform')(x)
    x = tf.keras.layers.Dropout(0.5)(x)
    outputs = tf.keras.layers.Dense(num_classes, activation=None, name='logits')(x)
    return tf.keras.Model(inputs=inputs, outputs=outputs, name='eurosat_model')

model = build_eurosat_model()

# ------------------------------
# 3. Compile and Train
# ------------------------------
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

os.makedirs(SAVE_DIR, exist_ok=True)
callbacks = [
    tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=7, restore_best_weights=True),
    tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3),
    tf.keras.callbacks.ModelCheckpoint(os.path.join(SAVE_DIR, "best_eurosat_model.h5"), save_best_only=True, monitor='val_accuracy')
]

print("\n🚀 Starting training...")
history = model.fit(train_dl, epochs=EPOCHS, validation_data=test_dl, callbacks=callbacks)

# ------------------------------
# 4. Visualization
# ------------------------------
# نمودار تاریخچه آموزش
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.figure(figsize=(8, 4))
plt.plot(acc, label='Train Acc'); plt.plot(val_acc, label='Val Acc')
plt.legend(); plt.title('Accuracy'); plt.show()

# ماتریس درهم‌ریختگی
y_true, y_pred = [], []
for images, labels in test_dl:
    preds = model.predict(images, verbose=0)
    y_true.extend(labels.numpy()); y_pred.extend(np.argmax(preds, axis=1))

plt.figure(figsize=(10, 8))
sns.heatmap(confusion_matrix(y_true, y_pred), annot=True, fmt='d', xticklabels=class_names, yticklabels=class_names)
plt.title('Confusion Matrix'); plt.show()
# Out:
# Downloading to /root/.cache/kagglehub/datasets/apollo2506/eurosat-dataset/6.archive...
# 100%|██████████| 2.04G/2.04G [00:18<00:00, 119MB/s]
# Extracting files...
# Loading EuroSAT dataset from directory...
# Found 27000 files belonging to 10 classes.
# Using 21600 files for training.
# Found 27000 files belonging to 10 classes.
# Using 5400 files for validation.
# Classes found: ['AnnualCrop', 'Forest', 'HerbaceousVegetation', 'Highway', 'Industrial', 'Pasture', 'PermanentCrop', 'Residential', 'River', 'SeaLake']
#
# 🚀 Starting training...
# Epoch 1/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.2292 - loss: 8.7946
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 37s 85ms/step - accuracy: 0.2624 - loss: 3.6186 - val_accuracy: 0.2954 - val_loss: 1.7999 - learning_rate: 0.0010
# Epoch 2/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.3510 - loss: 1.7332
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 24s 71ms/step - accuracy: 0.3652 - loss: 1.6840 - val_accuracy: 0.3220 - val_loss: 2.3847 - learning_rate: 0.0010
# Epoch 3/50
# 337/338 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.4051 - loss: 1.5572
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 24s 69ms/step - accuracy: 0.4093 - loss: 1.5477 - val_accuracy: 0.4881 - val_loss: 1.4617 - learning_rate: 0.0010
# Epoch 4/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.4374 - loss: 1.4936
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 24s 69ms/step - accuracy: 0.4383 - loss: 1.4828 - val_accuracy: 0.5952 - val_loss: 1.3340 - learning_rate: 0.0010
# Epoch 5/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 23s 68ms/step - accuracy: 0.4741 - loss: 1.3905 - val_accuracy: 0.5711 - val_loss: 1.1111 - learning_rate: 0.0010
# Epoch 6/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 23s 67ms/step - accuracy: 0.5004 - loss: 1.3334 - val_accuracy: 0.5341 - val_loss: 1.4190 - learning_rate: 0.0010
# Epoch 7/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 22s 65ms/step - accuracy: 0.5190 - loss: 1.3078 - val_accuracy: 0.5030 - val_loss: 2.0381 - learning_rate: 0.0010
# Epoch 8/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 23s 66ms/step - accuracy: 0.5390 - loss: 1.2472 - val_accuracy: 0.5944 - val_loss: 1.3771 - learning_rate: 0.0010
# Epoch 9/50
# 337/338 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.5604 - loss: 1.1649
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 24s 70ms/step - accuracy: 0.5631 - loss: 1.1693 - val_accuracy: 0.6539 - val_loss: 1.1219 - learning_rate: 5.0000e-04
# Epoch 10/50
# 337/338 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.5745 - loss: 1.1547
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 24s 70ms/step - accuracy: 0.5792 - loss: 1.1469 - val_accuracy: 0.6793 - val_loss: 0.8646 - learning_rate: 5.0000e-04
# Epoch 11/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 23s 68ms/step - accuracy: 0.5879 - loss: 1.1119 - val_accuracy: 0.4928 - val_loss: 2.0358 - learning_rate: 5.0000e-04
# Epoch 12/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 23s 68ms/step - accuracy: 0.6031 - loss: 1.0878 - val_accuracy: 0.4978 - val_loss: 2.0335 - learning_rate: 5.0000e-04
# Epoch 13/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 23s 67ms/step - accuracy: 0.6121 - loss: 1.0721 - val_accuracy: 0.6433 - val_loss: 1.3476 - learning_rate: 5.0000e-04
# Epoch 14/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6258 - loss: 1.0263
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 23s 68ms/step - accuracy: 0.6315 - loss: 1.0185 - val_accuracy: 0.7139 - val_loss: 0.8878 - learning_rate: 2.5000e-04
# Epoch 15/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6418 - loss: 0.9874
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 41s 70ms/step - accuracy: 0.6403 - loss: 0.9918 - val_accuracy: 0.7417 - val_loss: 0.7956 - learning_rate: 2.5000e-04
# Epoch 16/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 23s 69ms/step - accuracy: 0.6474 - loss: 0.9816 - val_accuracy: 0.5402 - val_loss: 1.8270 - learning_rate: 2.5000e-04
# Epoch 17/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 23s 68ms/step - accuracy: 0.6477 - loss: 0.9793 - val_accuracy: 0.5741 - val_loss: 1.6134 - learning_rate: 2.5000e-04
# Epoch 18/50
# 337/338 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6584 - loss: 0.9603
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 23s 68ms/step - accuracy: 0.6582 - loss: 0.9564 - val_accuracy: 0.7674 - val_loss: 0.7654 - learning_rate: 2.5000e-04
# Epoch 19/50
# 337/338 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6474 - loss: 0.9631
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 42s 70ms/step - accuracy: 0.6487 - loss: 0.9641 - val_accuracy: 0.7896 - val_loss: 0.6471 - learning_rate: 2.5000e-04
# Epoch 20/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 23s 68ms/step - accuracy: 0.6574 - loss: 0.9521 - val_accuracy: 0.7633 - val_loss: 0.6548 - learning_rate: 2.5000e-04
# Epoch 21/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 23s 67ms/step - accuracy: 0.6591 - loss: 0.9412 - val_accuracy: 0.5270 - val_loss: 2.1892 - learning_rate: 2.5000e-04
# Epoch 22/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 22s 66ms/step - accuracy: 0.6660 - loss: 0.9307 - val_accuracy: 0.7756 - val_loss: 0.7686 - learning_rate: 2.5000e-04
# Epoch 23/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 23s 66ms/step - accuracy: 0.6739 - loss: 0.8993 - val_accuracy: 0.6741 - val_loss: 1.2128 - learning_rate: 1.2500e-04
# Epoch 24/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 23s 67ms/step - accuracy: 0.6750 - loss: 0.8926 - val_accuracy: 0.7522 - val_loss: 0.7855 - learning_rate: 1.2500e-04
# Epoch 25/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 23s 68ms/step - accuracy: 0.6770 - loss: 0.8877 - val_accuracy: 0.7372 - val_loss: 0.8205 - learning_rate: 1.2500e-04
# Epoch 26/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 41s 66ms/step - accuracy: 0.6915 - loss: 0.8592 - val_accuracy: 0.7781 - val_loss: 0.6830 - learning_rate: 6.2500e-05

# %%
# ------------------------------
# 5. Display Sample Predictions
# ------------------------------
import matplotlib.pyplot as plt

def plot_sample_predictions(model, test_dataset, class_names):
    # گرفتن یک batch از داده‌های تست
    images, labels = next(iter(test_dataset))

    # پیش‌بینی
    predictions = model.predict(images)
    predicted_classes = tf.argmax(predictions, axis=1)

    # رسم ۹ نمونه اول
    plt.figure(figsize=(12, 12))
    for i in range(9):
        plt.subplot(3, 3, i + 1)
        # نرمال‌سازی تصویر برای نمایش (چون در مدل بر بازه [0, 1] است)
        plt.imshow(images[i].numpy())

        actual = class_names[labels[i]]
        pred = class_names[predicted_classes[i]]

        plt.title(f"True: {actual}\nPred: {pred}")
        plt.axis('off')

    plt.tight_layout()
    plt.show()

# اجرای تابع (با فرض اینکه model و test_dl و train_ds تعریف شده‌اند)
plot_sample_predictions(model, test_dl, train_ds.class_names)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
